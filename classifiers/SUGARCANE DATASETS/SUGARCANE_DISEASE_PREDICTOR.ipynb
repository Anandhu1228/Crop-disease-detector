# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
IMGSZ = 256
B_SIZE = 32
CHANNEL_SIZE = 3
EPOCHS = 40

# %%
datasets = tf.keras.preprocessing.image_dataset_from_directory(
    "SUGARCANE DATASETS",
    image_size=(IMGSZ,IMGSZ),
    shuffle=True,
    batch_size=B_SIZE
)
# Out:
# Found 2521 files belonging to 5 classes.

# %%
CLASS_NAMES = datasets.class_names
CLASS_NAMES
# Out:
# ['Sugercane___healthy',
#  'Sugercane___mosaic',
#  'Sugercane___red_rot',
#  'Sugercane___rust',
#  'Sugercane___yellow_leaf']

# %%
for image_batch, label_batch in datasets.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(CLASS_NAMES[label_batch[0]])

# %%
for image_batch, label_batch in datasets.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(CLASS_NAMES[label_batch[0]])

# %%
def get_train_test_eval_dataset(datasets, train_size=0.8, val_size=0.1, test_size=0.1, shuffle=True, shuffle_size=10000):
    assert (train_size + test_size + val_size) == 1
    
    ds_size = len(datasets)
    
    if shuffle:
        datasets = datasets.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_size * ds_size)
    val_size = int(val_size * ds_size)
    
    train_dataset = datasets.take(train_size)    
    val_dataset = datasets.skip(train_size).take(val_size)
    test_dataset = datasets.skip(train_size).skip(val_size)
    
    return train_dataset, val_dataset, test_dataset

train_dataset, val_dataset, test_dataset = get_train_test_eval_dataset(datasets)

print("LENGTH OF TRAIN DATASET : ",len(train_dataset))
print("LENGTH OF TEST DATASET : ",len(test_dataset))
print("LENGTH OF EVAL DATASET : ",len(val_dataset))
# Out:
# LENGTH OF TRAIN DATASET :  63
# LENGTH OF TEST DATASET :  9
# LENGTH OF EVAL DATASET :  7

# %%
train_dataset = train_dataset.cache().shuffle(1000)
test_dataset = test_dataset.cache().shuffle(1000)
val_dataset = val_dataset.cache().shuffle(1000)

# %%
resize_rescale = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(IMGSZ,IMGSZ),
    tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
])

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

model = tf.keras.Sequential([
    resize_rescale,
    data_augmentation,
    tf.keras.layers.Conv2D(32,(3,3),activation="relu",input_shape = (IMGSZ,IMGSZ,CHANNEL_SIZE)),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64,activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5,activation="softmax")

])

model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history_rec = model.fit(
    train_dataset,
    epochs=EPOCHS,
    batch_size=B_SIZE,
    verbose=1,
    validation_data=val_dataset
)
# Out:
# Epoch 1/40
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 105s 2s/step - loss: 1.6053 - accuracy: 0.2207 - val_loss: 1.6126 - val_accuracy: 0.1562
# Epoch 2/40
# 63/63 [==============================] - 92s 1s/step - loss: 1.4432 - accuracy: 0.3641 - val_loss: 1.4157 - val_accuracy: 0.3705
# Epoch 3/40
# 63/63 [==============================] - 93s 1s/step - loss: 1.3059 - accuracy: 0.4360 - val_loss: 1.3534 - val_accuracy: 0.4598
# Epoch 4/40
# 63/63 [==============================] - 96s 2s/step - loss: 1.1416 - accuracy: 0.5243 - val_loss: 0.9928 - val_accuracy: 0.5491
# Epoch 5/40
# 63/63 [==============================] - 94s 1s/step - loss: 0.9772 - accuracy: 0.6012 - val_loss: 0.8753 - val_accuracy: 0.6607
# Epoch 6/40
# 63/63 [==============================] - 95s 2s/step - loss: 0.8701 - accuracy: 0.6305 - val_loss: 0.7934 - val_accuracy: 0.6875
# Epoch 7/40
# 63/63 [==============================] - 95s 2s/step - loss: 0.7941 - accuracy: 0.6994 - val_loss: 0.7518 - val_accuracy: 0.6786
# Epoch 8/40
# 63/63 [==============================] - 88s 1s/step - loss: 0.7075 - accuracy: 0.7212 - val_loss: 0.7406 - val_accuracy: 0.6786
# Epoch 9/40
# 63/63 [==============================] - 90s 1s/step - loss: 0.6586 - accuracy: 0.7411 - val_loss: 0.7641 - val_accuracy: 0.6696
# Epoch 10/40
# 63/63 [==============================] - 92s 1s/step - loss: 0.6461 - accuracy: 0.7455 - val_loss: 0.5860 - val_accuracy: 0.7545
# Epoch 11/40
# 63/63 [==============================] - 95s 2s/step - loss: 0.5958 - accuracy: 0.7669 - val_loss: 0.6493 - val_accuracy: 0.7411
# Epoch 12/40
# 63/63 [==============================] - 96s 2s/step - loss: 0.5812 - accuracy: 0.7743 - val_loss: 0.5420 - val_accuracy: 0.7857
# Epoch 13/40
# 63/63 [==============================] - 96s 2s/step - loss: 0.5197 - accuracy: 0.8011 - val_loss: 0.5553 - val_accuracy: 0.7812
# Epoch 14/40
# 63/63 [==============================] - 96s 2s/step - loss: 0.5156 - accuracy: 0.8016 - val_loss: 0.4445 - val_accuracy: 0.8259
# Epoch 15/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.4789 - accuracy: 0.8189 - val_loss: 0.4810 - val_accuracy: 0.8036
# Epoch 16/40
# 63/63 [==============================] - 96s 2s/step - loss: 0.4810 - accuracy: 0.8095 - val_loss: 0.4480 - val_accuracy: 0.8214
# Epoch 17/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.4326 - accuracy: 0.8358 - val_loss: 0.4027 - val_accuracy: 0.8571
# Epoch 18/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.4339 - accuracy: 0.8363 - val_loss: 0.4917 - val_accuracy: 0.7991
# Epoch 19/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.4237 - accuracy: 0.8388 - val_loss: 0.4865 - val_accuracy: 0.8080
# Epoch 20/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.4689 - accuracy: 0.8120 - val_loss: 0.4229 - val_accuracy: 0.8259
# Epoch 21/40
# 63/63 [==============================] - 97s 2s/step - loss: 0.3969 - accuracy: 0.8547 - val_loss: 0.3958 - val_accuracy: 0.8393
# Epoch 22/40
# 63/63 [==============================] - 96s 2s/step - loss: 0.3803 - accuracy: 0.8596 - val_loss: 0.4703 - val_accuracy: 0.8393
# Epoch 23/40
# 63/63 [==============================] - 98s 2s/step - loss: 0.3664 - accuracy: 0.8606 - val_loss: 0.3904 - val_accuracy: 0.8616
# Epoch 24/40
# 63/63 [==============================] - 98s 2s/step - loss: 0.4439 - accuracy: 0.8244 - val_loss: 0.4717 - val_accuracy: 0.8438
# Epoch 25/40
# 63/63 [==============================] - 90s 1s/step - loss: 0.3954 - accuracy: 0.8502 - val_loss: 0.3693 - val_accuracy: 0.8661
# Epoch 26/40
# 63/63 [==============================] - 91s 1s/step - loss: 0.3477 - accuracy: 0.8626 - val_loss: 0.5285 - val_accuracy: 0.8036
# Epoch 27/40
# 63/63 [==============================] - 93s 1s/step - loss: 0.3532 - accuracy: 0.8681 - val_loss: 0.4277 - val_accuracy: 0.8125
# Epoch 28/40
# 63/63 [==============================] - 93s 1s/step - loss: 0.3582 - accuracy: 0.8656 - val_loss: 0.4370 - val_accuracy: 0.8393
# Epoch 29/40
# 63/63 [==============================] - 93s 1s/step - loss: 0.3616 - accuracy: 0.8576 - val_loss: 0.3982 - val_accuracy: 0.8750
# Epoch 30/40
# 63/63 [==============================] - 98s 2s/step - loss: 0.3305 - accuracy: 0.8745 - val_loss: 0.3051 - val_accuracy: 0.9018
# Epoch 31/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.3047 - accuracy: 0.8829 - val_loss: 0.3257 - val_accuracy: 0.8929
# Epoch 32/40
# 63/63 [==============================] - 107s 2s/step - loss: 0.3145 - accuracy: 0.8829 - val_loss: 0.3544 - val_accuracy: 0.8616
# Epoch 33/40
# 63/63 [==============================] - 102s 2s/step - loss: 0.3079 - accuracy: 0.8810 - val_loss: 0.3294 - val_accuracy: 0.8839
# Epoch 34/40
# 63/63 [==============================] - 98s 2s/step - loss: 0.2856 - accuracy: 0.8968 - val_loss: 0.3477 - val_accuracy: 0.8393
# Epoch 35/40
# 63/63 [==============================] - 102s 2s/step - loss: 0.2694 - accuracy: 0.8953 - val_loss: 0.2981 - val_accuracy: 0.8929
# Epoch 36/40
# 63/63 [==============================] - 107s 2s/step - loss: 0.2802 - accuracy: 0.8904 - val_loss: 0.3341 - val_accuracy: 0.8795
# Epoch 37/40
# 63/63 [==============================] - 101s 2s/step - loss: 0.3034 - accuracy: 0.8889 - val_loss: 0.3051 - val_accuracy: 0.8929
# Epoch 38/40
# 63/63 [==============================] - 105s 2s/step - loss: 0.2462 - accuracy: 0.9033 - val_loss: 0.2624 - val_accuracy: 0.9062
# Epoch 39/40
# 63/63 [==============================] - 100s 2s/step - loss: 0.2619 - accuracy: 0.8919 - val_loss: 0.3712 - val_accuracy: 0.8705
# Epoch 40/40
# 63/63 [==============================] - 99s 2s/step - loss: 0.2493 - accuracy: 0.9077 - val_loss: 0.2862 - val_accuracy: 0.8839

# %%
accuracy_pm = history_rec.history['accuracy']
loss_pm = history_rec.history['loss']
val_accuracy_pm = history_rec.history['val_accuracy']
val_loss_pm = history_rec.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), accuracy_pm, label='Training Accuracy')
plt.plot(range(EPOCHS), val_accuracy_pm, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss_pm, label='Training Loss')
plt.plot(range(EPOCHS), val_loss_pm, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_dataset)
# Out:
# 9/9 [==============================] - 7s 449ms/step - loss: 0.4024 - accuracy: 0.8819
# [0.4023881256580353, 0.8819444179534912]

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        IMG = images[i].numpy()
        plt.imshow(IMG.astype("uint8"))

        img_array = tf.expand_dims(IMG, 0)
        predictions = model.predict(img_array)

        predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
        confidence = round(100 * (np.max(predictions[0])), 2)
        actual_class = CLASS_NAMES[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
model_version = 9
model.save(f"./models/{model_version}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/9\assets
# INFO:tensorflow:Assets written to: ./models/9\assets
