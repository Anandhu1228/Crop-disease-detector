# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
IMGSZ = 256
B_SIZE = 32
CHANNEL_SIZE = 3
EPOCHS = 25

# %%
datasets = tf.keras.preprocessing.image_dataset_from_directory(
    "STRAWBERRY DATASETS",
    image_size=(IMGSZ,IMGSZ),
    shuffle=True,
    batch_size=B_SIZE
)
# Out:
# Found 1565 files belonging to 2 classes.

# %%
CLASS_NAMES = datasets.class_names
CLASS_NAMES
# Out:
# ['Strawberry___healthy', 'Strawberry___leaf_scorch']

# %%
for image_batch, label_batch in datasets.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(CLASS_NAMES[label_batch[0]])

# %%
for image_batch, label_batch in datasets.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(CLASS_NAMES[label_batch[0]])

# %%
def get_train_test_eval_dataset(datasets, train_size=0.8, val_size=0.1, test_size=0.1, shuffle=True, shuffle_size=10000):
    assert (train_size + test_size + val_size) == 1
    
    ds_size = len(datasets)
    
    if shuffle:
        datasets = datasets.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_size * ds_size)
    val_size = int(val_size * ds_size)
    
    train_dataset = datasets.take(train_size)    
    val_dataset = datasets.skip(train_size).take(val_size)
    test_dataset = datasets.skip(train_size).skip(val_size)
    
    return train_dataset, val_dataset, test_dataset

train_dataset, val_dataset, test_dataset = get_train_test_eval_dataset(datasets)

print("LENGTH OF TRAIN DATASET : ",len(train_dataset))
print("LENGTH OF TEST DATASET : ",len(test_dataset))
print("LENGTH OF EVAL DATASET : ",len(val_dataset))
# Out:
# LENGTH OF TRAIN DATASET :  39
# LENGTH OF TEST DATASET :  6
# LENGTH OF EVAL DATASET :  4

# %%
train_dataset = train_dataset.cache().shuffle(1000)
test_dataset = test_dataset.cache().shuffle(1000)
val_dataset = val_dataset.cache().shuffle(1000)

# %%
resize_rescale = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(IMGSZ,IMGSZ),
    tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
])

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

model = tf.keras.Sequential([
    resize_rescale,
    data_augmentation,
    tf.keras.layers.Conv2D(32,(3,3),activation="relu",input_shape = (IMGSZ,IMGSZ,CHANNEL_SIZE)),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64,activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(2,activation="softmax")
])

model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history_rec = model.fit(
    train_dataset,
    epochs=EPOCHS,
    batch_size=B_SIZE,
    verbose=1,
    validation_data=val_dataset
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 39/39 [==============================] - 59s 1s/step - loss: 0.4533 - accuracy: 0.7703 - val_loss: 0.0715 - val_accuracy: 0.9766
# Epoch 2/25
# 39/39 [==============================] - 54s 1s/step - loss: 0.0677 - accuracy: 0.9831 - val_loss: 0.0453 - val_accuracy: 0.9766
# Epoch 3/25
# 39/39 [==============================] - 55s 1s/step - loss: 0.0271 - accuracy: 0.9936 - val_loss: 0.0625 - val_accuracy: 0.9766
# Epoch 4/25
# 39/39 [==============================] - 53s 1s/step - loss: 0.0190 - accuracy: 0.9952 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 5/25
# 39/39 [==============================] - 54s 1s/step - loss: 0.0295 - accuracy: 0.9920 - val_loss: 0.0571 - val_accuracy: 0.9922
# Epoch 6/25
# 39/39 [==============================] - 53s 1s/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.0444 - val_accuracy: 0.9844
# Epoch 7/25
# 39/39 [==============================] - 55s 1s/step - loss: 0.0088 - accuracy: 0.9960 - val_loss: 0.0168 - val_accuracy: 0.9922
# Epoch 8/25
# 39/39 [==============================] - 62s 2s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9922
# Epoch 9/25
# 39/39 [==============================] - 69s 2s/step - loss: 7.3358e-04 - accuracy: 0.9992 - val_loss: 0.0089 - val_accuracy: 0.9922
# Epoch 10/25
# 39/39 [==============================] - 69s 2s/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 11/25
# 39/39 [==============================] - 68s 2s/step - loss: 9.2518e-04 - accuracy: 1.0000 - val_loss: 1.2975e-05 - val_accuracy: 1.0000
# Epoch 12/25
# 39/39 [==============================] - 143s 4s/step - loss: 6.7820e-05 - accuracy: 1.0000 - val_loss: 1.0615e-05 - val_accuracy: 1.0000
# Epoch 13/25
# 39/39 [==============================] - 68s 2s/step - loss: 7.2450e-05 - accuracy: 1.0000 - val_loss: 6.5124e-06 - val_accuracy: 1.0000
# Epoch 14/25
# 39/39 [==============================] - 69s 2s/step - loss: 1.0181e-05 - accuracy: 1.0000 - val_loss: 5.8756e-06 - val_accuracy: 1.0000
# Epoch 15/25
# 39/39 [==============================] - 491s 13s/step - loss: 6.8746e-05 - accuracy: 1.0000 - val_loss: 1.0616e-05 - val_accuracy: 1.0000
# Epoch 16/25
# 39/39 [==============================] - 48s 1s/step - loss: 8.4773e-04 - accuracy: 0.9992 - val_loss: 6.7586e-05 - val_accuracy: 1.0000
# Epoch 17/25
# 39/39 [==============================] - 50s 1s/step - loss: 6.0620e-05 - accuracy: 1.0000 - val_loss: 7.8972e-06 - val_accuracy: 1.0000
# Epoch 18/25
# 39/39 [==============================] - 51s 1s/step - loss: 2.5603e-05 - accuracy: 1.0000 - val_loss: 7.7397e-06 - val_accuracy: 1.0000
# Epoch 19/25
# 39/39 [==============================] - 51s 1s/step - loss: 5.1444e-06 - accuracy: 1.0000 - val_loss: 6.8696e-06 - val_accuracy: 1.0000
# Epoch 20/25
# 39/39 [==============================] - 52s 1s/step - loss: 8.5191e-06 - accuracy: 1.0000 - val_loss: 5.2084e-06 - val_accuracy: 1.0000
# Epoch 21/25
# 39/39 [==============================] - 53s 1s/step - loss: 2.0290e-05 - accuracy: 1.0000 - val_loss: 3.2100e-06 - val_accuracy: 1.0000
# Epoch 22/25
# 39/39 [==============================] - 53s 1s/step - loss: 3.3530e-06 - accuracy: 1.0000 - val_loss: 3.3636e-06 - val_accuracy: 1.0000
# Epoch 23/25
# 39/39 [==============================] - 54s 1s/step - loss: 2.0455e-05 - accuracy: 1.0000 - val_loss: 8.3108e-06 - val_accuracy: 1.0000
# Epoch 24/25
# 39/39 [==============================] - 54s 1s/step - loss: 3.4733e-06 - accuracy: 1.0000 - val_loss: 7.4129e-06 - val_accuracy: 1.0000
# Epoch 25/25
# 39/39 [==============================] - 54s 1s/step - loss: 1.2260e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000

# %%
accuracy_pm = history_rec.history['accuracy']
loss_pm = history_rec.history['loss']
val_accuracy_pm = history_rec.history['val_accuracy']
val_loss_pm = history_rec.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), accuracy_pm, label='Training Accuracy')
plt.plot(range(EPOCHS), val_accuracy_pm, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss_pm, label='Training Loss')
plt.plot(range(EPOCHS), val_loss_pm, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_dataset)
# Out:
# 6/6 [==============================] - 3s 333ms/step - loss: 1.3908e-07 - accuracy: 1.0000
# [1.390767607745147e-07, 1.0]

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        IMG = images[i].numpy()
        plt.imshow(IMG.astype("uint8"))

        img_array = tf.expand_dims(IMG, 0)
        predictions = model.predict(img_array)

        predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
        confidence = round(100 * (np.max(predictions[0])), 2)
        actual_class = CLASS_NAMES[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
model_version = 6
model.save(f"./models/{model_version}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/6\assets
# INFO:tensorflow:Assets written to: ./models/6\assets
